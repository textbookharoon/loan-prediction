# %% [markdown]
# Import dependencies

# %%
import pandas as pd
import seaborn as sns
from sklearn import svm
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# Import datasets

# %%
train_dataset = pd.read_csv("./Datasets/loan_dataset/train_dataset.csv")
test_dataset = pd.read_csv("./Datasets/loan_dataset/test_dataset.csv")

print(train_dataset.shape)
print(train_dataset.head())
print(train_dataset.describe())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 train_dataset = pd.read_csv("./Datasets/loan_dataset/train_dataset.csv")
#       2 test_dataset = pd.read_csv("./Datasets/loan_dataset/test_dataset.csv")
#       4 print(train_dataset.shape)
#
# ...

# %% [markdown]
# Convert categorical columns to numerical ones

# %%
categorical_cols = {
    "Loan_Status": {"No": 0, "Yes": 1},
    "Gender": {"Female": 0, "Male": 1},
    "Self_Employed": {"No": 0, "Yes": 1},
    "Property_Area": {"Rural": 0, "Urban": 1, "Semiurban": 2},
    "Education": {"Graduate": 0, "Not Graduate": 1}}

# %% [markdown]
# Identify missing values in each column

# %%
train_dataset.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 train_dataset.isnull().sum()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'isnull'

# %% [markdown]
# Handle missing values

# %%
for col in categorical_cols:
    train_dataset[col].fillna(train_dataset[col].mode()[0], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 for col in categorical_cols:
# ----> 2     train_dataset[col].fillna(train_dataset[col].mode()[0], inplace=True)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %% [markdown]
# Separate features and target from the training dataset

# %%
X_train = train_dataset.drop(columns=["Loan_ID", "Loan_Status"])

# %% [markdown]
# Remove Loan_Status column from the test dataset

# %% [markdown]
# Data visualisation: Marital status

# %%
sns.countplot(x="Married", hue="Loan_Status", data=train_dataset)
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
sns.countplot(x="Education", hue="Loan_Status", data=train_dataset)
# Out:
# <Axes: xlabel='Education', ylabel='count'>
